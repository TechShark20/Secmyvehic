# %%
#@title Effect of distance and preprocessing time
#@markdown  The code preprocesses and gives visualisation for time with effect of changing min face parameter in the  face detection
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#@title MIn face 90

Threesold90="""319
,289
,323
,322
,298
,331
,333
,278
,321
,321
,331
,297
,378
,312
,325
,312
,398
,357
,344
,343
,306
,317
,304
,324
,326
,312
,323
,327
,293
,305
,321
,309
,308
,312
,328
,333
,316
,329
,346
,345
,345
,319
,332
,318
,353
,317
,299
,303
,315
,370
,345
,328
,391
,313
,366
,330
,346
,360
,346
,
"""
Threesold90 =Threesold90.split(',')
for i in range(0,len(Threesold90)):
   Threesold90[i]=Threesold90[i].replace('\n','')
Threesold90 = [val for val in Threesold90 if val.strip()]


Threesold90=np.array(Threesold90)
Threesold90 = Threesold90.astype(int)
mean90=np.mean(Threesold90)

# %%
#@title MIn face 85
Threesold85="""313
,316
,330
,357
,317
,317
,317
,304
,305
,304
,305
,318
,330
,319
,318
,359
,360
,331
,287
,319
,314
,331
,316
,305
,318
,333
,334
,319
,335
,298
,327
,319
,347
,330
,338
,348
,400
,392
,439
,426
,428
,442
,487
,486
,399
,327
,336
,362
,353
,327
,340
,327
,321
,293
,309
,296
,323
,288
,344
,337
,368
,347
,321
,307
,317

,"""

Threesold85 =Threesold85.split(',')
for i in range(0,len(Threesold85)):
   Threesold85[i]=Threesold85[i].replace('\n','')

Threesold85 = [val for val in Threesold85 if val.strip()]


Threesold85=np.array(Threesold85)
Threesold85 = Threesold85.astype(int)
mean85=np.mean(Threesold85)

# %%
#@title MIn face 80
Threesold80="""
317
,291
,319
,334
,310
,317
,322
,317
,351
,297
,335
,309
,321
,308
,320
,310
,308
,351
,351
,310
,351
,351
,352
,351
,351
,313
,341
,314
,326
,312
,341
,313
,313
,301
,314
,330
,329
,328
,342
,315
,407
,317
,343
,328
,330
,343
,392
,395
,490
,316
,296
,327
,369
,331
,350
,325
,310
,326
,329
,398
,361
,341
,341
,355
,338
,

"""
Threesold80 =Threesold80.split(',')
for i in range(0,len(Threesold80)):
   Threesold80[i]=Threesold80[i].replace('\n','')
Threesold80 = [val for val in Threesold80 if val.strip()]


Threesold80=np.array(Threesold80)
Threesold80 = Threesold80.astype(int)
mean80=np.mean(Threesold80)

# %%
#@title MIn face 75
Threesold75="""
330
,331
,343
,331
,333
,391
,384
,446
,382
,394
,394
,409
,396
,360
,407
,343
,310
,470
,460
,409
,505
,348
,410
,403
,359
,335
,351
,336
,338
,428
,348
,361
,376
,359
,313
,339
,327
,369
,315
,315
,452
,490
,385
,344
,403
,387
,372
,401
,342
,358
,386
,396
,383
,355
,354
,354
,367
,367
,355
,


"""
Threesold75 =Threesold75.split(',')
for i in range(0,len(Threesold75)):
   Threesold75[i]=Threesold75[i].replace('\n','')
Threesold75 = [val for val in Threesold75 if val.strip()]


Threesold75=np.array(Threesold75)
Threesold75 = Threesold75.astype(int)
mean75=np.mean(Threesold75)

# %%
#@title MIn face 70
Threesold70="""
312
,396
,347
,384
,319
,360
,400
,394
,385
,426
,387
,402
,428
,428
,427
,454
,451
,463
,454
,482
,494
,553
,412
,380
,343
,331
,345
,346
,332
,319
,331
,333
,348
,359
,373
,367
,385
,400
,458
,403
,371
,455
,372
,371
,356
,355
,356
,371
,360
,395
,387
,387
,375
,362







"""

Threesold70 =Threesold70.split(',')
for i in range(0,len(Threesold70)):
   Threesold70[i]=Threesold70[i].replace('\n','')
Threesold70 = [val for val in Threesold70 if val.strip()]


Threesold70=np.array(Threesold70)
Threesold70 = Threesold70.astype(int)
mean70=np.mean(Threesold70)

# %%
#@title Min Face 65
Threesold65="""
408
,446
,473
,467
,436
,562
,535
,485
,486
,603
,575
,560
,516
,479
,477
,517
,535
,478
,570
,573
,509
,527
,522
,518
,583
,514
,489
,600
,453
,417
,493
,476
,546
,525
,426
,412
,429
,401
,442
,469
,430
,483
,469
,520
,442
,516
,567
,560
,526
,507
,484
,448
,487
,442
,507
,460
,507
,443
,481
,492
,479
,518
,522
,404
,353
,397
,385
,340
,353
,353
,340
,340
,379
,361
,402
,408
,443
,391
,420
,374
,381
,452
,438
,

"""
Threesold65 =Threesold65.split(',')
for i in range(0,len(Threesold65)):
   Threesold65[i]=Threesold65[i].replace('\n','')
Threesold65 = [val for val in Threesold65 if val.strip()]


Threesold65=np.array(Threesold65)
Threesold65 = Threesold65.astype(int)
mean65=np.mean(Threesold65)

# %%
#@title min face 60
Threesold60="""
470
,475
,498
,501
,505
,551
,498
,505
,457
,447
,496
,517
,449
,409
,411
,431
,450
,425
,439
,460
,461
,401
,410
,400
,427
,441
,441
,522
,469
,468
,421
,416
,468
,441
,443
,442
,430
,468
,419
,500
,557
,435
,475
,436
,531
,495
,534
,512
,473
,450
,494
,474
,428
,485
,452
,447
,392
,452
,358
,449
,424
,538
,


"""
Threesold60 =Threesold60.split(',')
for i in range(0,len(Threesold60)):
   Threesold60[i]=Threesold60[i].replace('\n','')

Threesold60 = [val for val in Threesold60 if val.strip()]


Threesold60=np.array(Threesold60)
Threesold60 = Threesold60.astype(int)
mean60=np.mean(Threesold60)

# %%
#@title Storing the means

st1 = 'mean'
list1=[]
list2=[]
for i in range(60,95,5):
  st=st1+str(i)
  val=globals()[st]
  list1.append(val)
  list2.append(str(i))

data={'mean':list2,'value':list1}
df=pd.DataFrame(data)

# %%
#@title Plotting the results -Scatterplot
sns.scatterplot(data=df,x='mean',y='value')
plt.xlabel('Min detection confidence ')
plt.ylabel('Avg Time in ms')
plt.savefig('scatterminface.png', dpi=300)
plt.show()

# %%
#@title Plotting the results -BarPlot
sns.barplot(data=df,x='mean',y='value')
plt.xlabel('Min detection confidence ')
plt.ylabel('Avg Time in ms')

plt.savefig('Barminface.png', dpi=300)
plt.show()
